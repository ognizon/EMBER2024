# %%
import thrember

parquet_paths = thrember.create_parquet_features("/home/seema/ajvad/Datasets/ember2024/")
print(parquet_paths)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 import thrember
# ----> 3 parquet_paths = thrember.create_parquet_features("/home/seema/ajvad/Datasets/ember2024/")
#       4 print(parquet_paths)
#
# File ~/anaconda3/envs/ajvad/lib/python3.12/site-packages/thrember/model.py:590, in create_parquet_features(data_dir, subsets, output_dir, batch_size, compression, use_vectorized)
#     588 for subset in subsets:
#     589     validate_subset(subset)
# --> 590     parquet_paths[subset] = write_subset_parquet(
#     591         data_path,
#     592         subset,
#     593         output_path=output_path / f"{subset}.parquet",
#     594         batch_size=batch_size,
#     595         compression=compression,
#     596         use_vectorized=use_vectorized,
#     597     )
#     598 return parquet_paths
#
# ...

# %%
thrember.download_dataset("/home/seema/ajvad/Datasets/ember2024/raw_jsonl", file_type="PE")
# Out:
# Unzipping...
# Unzipping...
# Unzipping...
# Unzipping...
# Unzipping...
# Unzipping...

# %%
thrember.create_vectorized_features('/home/seema/ajvad/Datasets/ember2024/raw_jsonl/', create_parquet=True)
# Out:
# Preparing to vectorize raw features
# Vectorizing training set
# 100%|██████████| 4683000/4683000 [1:14:29<00:00, 1047.77it/s]
# Vectorizing test set
# 100%|██████████| 1080000/1080000 [17:12<00:00, 1045.63it/s]
# Vectorizing challenge set
# 100%|██████████| 6315/6315 [00:05<00:00, 1065.69it/s]
# Writing parquet feature files
# ...
# Writing challenge parquet: 100%|██████████| 6315/6315 [00:01<00:00, 3420.16it/s]
